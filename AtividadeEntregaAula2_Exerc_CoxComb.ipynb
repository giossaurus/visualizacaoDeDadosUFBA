# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv('/content/florence.csv')
df
# Out:
#              date  deaths      reason
# 0       April1854     1.4  Infectious
# 1       April1854     0.0      Wounds
# 2       April1854     7.0       Other
# 3         May1854     6.2  Infectious
# 4         May1854     0.0      Wounds
# 5         May1854     4.6       Other
# 6         Jun1854     4.7  Infectious
# 7         Jun1854     0.0      Wounds
# 8         Jun1854     2.5       Other
# 9        July1854   150.0  Infectious
# 10       July1854     0.0      Wounds
# 11       July1854     9.6       Other
# 12     August1854   328.5  Infectious
# 13     August1854     0.4      Wounds
# 14     August1854    11.9       Other
# 15  September1854   312.2  Infectious
# 16  September1854    32.1      Wounds
# 17  September1854    27.7       Other
# 18    October1854   197.0  Infectious
# 19    October1854    51.7      Wounds
# 20    October1854    50.1       Other
# 21   November1854   340.6  Infectious
# 22   November1854   115.8      Wounds
# 23   November1854    42.8       Other
# 24   December1854   631.5  Infectious
# 25   December1854    41.7      Wounds
# 26   December1854    48.0       Other
# 27    January1855  1022.8  Infectious
# 28    January1855    30.7      Wounds
# 29    January1855   120.0       Other
# 30   February1855   822.8  Infectious
# 31   February1855    16.3      Wounds
# 32   February1855   140.1       Other
# 33      March1855   480.3  Infectious
# 34      March1855    12.8      Wounds
# 35      March1855    68.6       Other

# %%
fig = px.bar_polar(df, r='deaths', theta='date', color='reason')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bee14dfe-7475-4dbe-add1-bc4f291ce2b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bee14dfe-7475-4dbe-add1-bc4f291ce2b4")) {                    Plotly.newPlot(                        "bee14dfe-7475-4dbe-add1-bc4f291ce2b4",                        [{"hovertemplate":"reason=Infectious\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Infectious","r":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"type":"barpolar"},{"hovertemplate":"reason=Wounds\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wounds","r":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"type":"barpolar"},{"hovertemplate":"reason=Other\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Other","r":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"type":"barpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %%
fig = px.bar(df, x='date', y='deaths', color='reason')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a567cda-90be-447a-9b4c-1544562bb925" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a567cda-90be-447a-9b4c-1544562bb925")) {                    Plotly.newPlot(                        "0a567cda-90be-447a-9b4c-1544562bb925",                        [{"alignmentgroup":"True","hovertemplate":"reason=Infectious\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Infectious","offsetgroup":"Infectious","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Wounds\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wounds","offsetgroup":"Wounds","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Other\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","col ...

# %%
fig = px.bar(df, x='date', y='deaths', color='reason', barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffdbb87e-3566-4fa9-8ea9-0a10a08cc6fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffdbb87e-3566-4fa9-8ea9-0a10a08cc6fa")) {                    Plotly.newPlot(                        "ffdbb87e-3566-4fa9-8ea9-0a10a08cc6fa",                        [{"alignmentgroup":"True","hovertemplate":"reason=Infectious\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Infectious","offsetgroup":"Infectious","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Wounds\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wounds","offsetgroup":"Wounds","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Other\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","col ...

# %%
fig = px.bar(df, x='deaths', y='date', color='reason', orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fcb99f41-3fcf-4c46-a41b-ab26bb5044b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcb99f41-3fcf-4c46-a41b-ab26bb5044b0")) {                    Plotly.newPlot(                        "fcb99f41-3fcf-4c46-a41b-ab26bb5044b0",                        [{"alignmentgroup":"True","hovertemplate":"reason=Infectious\u003cbr\u003edeaths=%{x}\u003cbr\u003edate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Infectious","offsetgroup":"Infectious","orientation":"h","showlegend":true,"textposition":"auto","x":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3],"xaxis":"x","y":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Wounds\u003cbr\u003edeaths=%{x}\u003cbr\u003edate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wounds","offsetgroup":"Wounds","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8],"xaxis":"x","y":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"reason=Other\u003cbr\u003edeaths=%{x}\u003cbr\u003edate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"h","showlegend":true,"textposition":"auto","x":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6],"xaxis":"x","y":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","col ...

# %%
fig = px.line_polar(df, r='deaths', theta='date', color='reason', line_close=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="464ff596-880c-4484-99c8-ccd65033f547" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("464ff596-880c-4484-99c8-ccd65033f547")) {                    Plotly.newPlot(                        "464ff596-880c-4484-99c8-ccd65033f547",                        [{"hovertemplate":"reason=Infectious\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Infectious","r":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3,1.4],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855","April1854"],"type":"scatterpolar"},{"hovertemplate":"reason=Wounds\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Wounds","r":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8,0.0],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855","April1854"],"type":"scatterpolar"},{"hovertemplate":"reason=Other\u003cbr\u003edeaths=%{r}\u003cbr\u003edate=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","r":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6,7.0],"showlegend":true,"subplot":"polar","theta":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855","April1854"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{" ...

# %%
fig = px.line(df, x='date', y='deaths', color='reason')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="032e6771-74e4-4114-8eec-89e352f5d584" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("032e6771-74e4-4114-8eec-89e352f5d584")) {                    Plotly.newPlot(                        "032e6771-74e4-4114-8eec-89e352f5d584",                        [{"hovertemplate":"reason=Infectious\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infectious","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Infectious","orientation":"v","showlegend":true,"x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[1.4,6.2,4.7,150.0,328.5,312.2,197.0,340.6,631.5,1022.8,822.8,480.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"reason=Wounds\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wounds","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Wounds","orientation":"v","showlegend":true,"x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[0.0,0.0,0.0,0.0,0.4,32.1,51.7,115.8,41.7,30.7,16.3,12.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"reason=Other\u003cbr\u003edate=%{x}\u003cbr\u003edeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":["April1854","May1854","Jun1854","July1854","August1854","September1854","October1854","November1854","December1854","January1855","February1855","March1855"],"xaxis":"x","y":[7.0,4.6,2.5,9.6,11.9,27.7,50.1,42.8,48.0,120.0,140.1,68.6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0 ...
